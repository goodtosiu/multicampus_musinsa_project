# %%
# 항상 첫 번째 셀
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
from db_client import RDSClient

def main():
    # 1. DB 클라이언트 인스턴스 생성 (이때 풀이 생성됨)
    db = RDSClient()
    
    # 2. 쿼리 실행 예시 (SELECT)
    print("--- 사용자 조회 ---")
    users = db.execute("SELECT * FROM crawl_target_id LIMIT 3;")
    if users:
        for user in users:
            print(user)


if __name__ == "__main__":
    main()
# Out:
# DB HOST: musinsa-data.c07kuo6ug98z.us-east-1.rds.amazonaws.com
# DB USER: admin
# DB PASSWORD: qkqajrwkrnrnrn9_
# DB NAME: musinsa
# DB PORT: 3306
# ✅ DB Engine (Pool) 생성 완료
# --- 사용자 조회 ---
# {'product_id': 70061, 'is_crawled': 0, 'created_at': datetime.datetime(2025, 11, 27, 1, 44)}
# {'product_id': 70063, 'is_crawled': 0, 'created_at': datetime.datetime(2025, 11, 27, 1, 44)}
# {'product_id': 70067, 'is_crawled': 0, 'created_at': datetime.datetime(2025, 11, 27, 1, 44)}

# %%
# !pip install tqdm

# %%
### 상품 id 크롤링

import requests
from tqdm import tqdm
import time
import csv

# %%
# 헤더 설정 (브라우저 요청과 동일하게)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://www.musinsa.com/category/003?gf=M&sortCode=SALE_ONE_YEAR_COUNT"
}

all_ids = set()
page = 1
page_size = 60  # API에서 요청하는 size
total_pages_estimate = 1350  # 약 7만7천개 / 60 -> 대략 3167 페이지, 안전하게 1350

# CSV 파일 열기 (중간 저장 가능)
with open("musinsa_bottom_ids.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["goodsNo"])  # 헤더

    # tqdm 진행률 표시
    for page in tqdm(range(1, total_pages_estimate + 1), desc="상품 ID 수집"):
        url = f"https://api.musinsa.com/api2/dp/v1/plp/goods?gf=M&sortCode=SALE_ONE_YEAR_COUNT&category=003&size={page_size}&caller=CATEGORY&page={page}&seen=0&seenAds="
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            data = response.json()
        except requests.exceptions.RequestException as e:
            print(f"\nRequest Error at page {page}: {e}")
            break
        except ValueError:
            print(f"\nJSON Decode Error at page {page}")
            print(response.text[:200])
            break

        items = data.get("data", {}).get("list", [])
        if not items:
            print(f"\n마지막 페이지 도달: page={page}")
            break

        for item in items:
            goods_no = item.get("goodsNo")
            if goods_no and goods_no not in all_ids:
                all_ids.add(goods_no)
                writer.writerow([goods_no])

        time.sleep(0.25)  # 서버 부담 방지

print(f"\n총 수집된 상품 ID: {len(all_ids)}")
print("CSV 파일로 저장 완료: musinsa_bottom_ids.csv")

# %%
# !pip install webdriver-manager
# !pip install pymysql

# %%
import re
import csv
import json
import pymysql
from pymysql.err import OperationalError
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import random

# %%
# ==========================================
# DB 설정
# ==========================================
DB_HOST = "musinsa-data.c07kuo6ug98z.us-east-1.rds.amazonaws.com"
DB_USER = "admin"
DB_PASSWORD = "qkqajrwkrnrnrn9_"
DB_NAME = "musinsa"
DB_PORT = 3306

# ==========================================
# DB 연결
# ==========================================
def get_connection():
    return pymysql.connect(
        host=DB_HOST, user=DB_USER, password=DB_PASSWORD,
        db=DB_NAME, port=DB_PORT, charset="utf8mb4"
    )

conn = get_connection()
cursor = conn.cursor()

# ==========================================
# product_bottom 테이블 컬럼 자동 읽기
# ==========================================
cursor.execute("SHOW COLUMNS FROM product_bottom")
db_cols = [row[0] for row in cursor.fetchall()]

print("DB 테이블 컬럼:", db_cols)
print("총 컬럼 수:", len(db_cols))

placeholders = ", ".join(["%s"] * len(db_cols))
insert_sql = f"""
INSERT INTO product_bottom ({", ".join(db_cols)})
VALUES ({placeholders})
"""

# ==========================================
# CSV에서 Product ID 읽기
# ==========================================
goods_ids = []
with open("musinsa_bottom_ids.csv", newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        goods_ids.append(row[0])

total_count = len(goods_ids)

# ==========================================
# 이미 저장된 상품 수 확인 → 재시작 기능
# ==========================================
cursor.execute("SELECT COUNT(*) FROM product_bottom")
saved_count = cursor.fetchone()[0]

print(f"이미 저장된 상품 수: {saved_count}개")
print(f"전체 상품 수: {total_count}")

start_index = saved_count
print(f"이번에 시작할 인덱스: {start_index}")

# ==========================================
# Selenium 설정
# ==========================================
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# ==========================================
# 공통 파싱 함수
# ==========================================
def extract_int(text):
    return int(re.sub(r"[^0-9]", "", text)) if text else None

def extract_number(text):
    if text is None:
        return None
    if "만" in text:
        try:
            return str(int(float(text.replace("만", "")) * 10000))
        except:
            return text
    cleaned = re.sub(r"[^0-9]", "", text)
    return cleaned if cleaned != "" else ""

def clean_product_name(name):
    return re.sub(r"-.*", "", name).strip()

# ==========================================
# 크롤링 시작
# ==========================================
print("크롤링 시작!")

for idx in range(start_index, total_count):

    gid = goods_ids[idx]
    print(f"[{idx+1}/{total_count}] 상품 {gid} 처리 중...")

    try:
        url = f"https://www.musinsa.com/products/{gid}"
        driver.get(url)
        time.sleep(random.uniform(0.8, 1.5))
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # -----------------------------
        # 1. 상품명
        # -----------------------------
        name_tag = soup.select_one("div[class*='GoodsName__Wrap'] span")
        product_name = clean_product_name(name_tag.get_text(strip=True)) if name_tag else None

        # 2. 브랜드
        brand_tag = soup.select_one("div[class*='Brand__Wrap'] span[class*='BrandName']")
        brand = re.sub(r"[0-9\.]+만", "", brand_tag.get_text(strip=True)).strip() if brand_tag else None

        # 3~5 정가/판매가/할인율
        normal_price = extract_int(soup.select_one("span.line-through").get_text()) if soup.select_one("span.line-through") else None
        sale_price = extract_int(soup.select_one("span[class*='CalculatedPrice']").get_text()) if soup.select_one("span[class*='CalculatedPrice']") else None
        discount = extract_int(soup.select_one("span[class*='DiscountRate']").get_text()) if soup.select_one("span[class*='DiscountRate']") else None

        # 6 카테고리
        cats = soup.select("div[class*='Category__Wrap'] a")
        upper_category = cats[0].get_text(strip=True) if len(cats) > 0 else None
        lower_category = cats[1].get_text(strip=True) if len(cats) > 1 else None

        # 7 성별
        gender = 0
        layout_boxes = soup.select("dl[class*='Layout__Wrap'] div[class*='Layout__Box']")
        if len(layout_boxes) > 1:
            dd = layout_boxes[1].find("dd")
            if dd:
                gtext = dd.get_text(strip=True)
                gender_map = {"남": 1, "여": 2, "공용": 0, "남녀공용": 0}
                gender = gender_map.get(gtext, 0)

        # 누적판매
        cumulative = ""
        for box in layout_boxes:
            dt = box.find("dt")
            dd = box.find("dd")
            if dt and dd and dt.get_text(strip=True) == "누적판매":
                cumulative = dd.get_text(strip=True)

        # 8 별점
        rating_tag = soup.select_one("div[class*='Review__Wrap'] span")
        rating = float(rating_tag.get_text(strip=True)) if rating_tag else None

        # 9 후기수
        review_cnt_tag = soup.select_one("div[class*='Review__Wrap'] span:nth-of-type(2)")
        review_cnt = int(extract_number(review_cnt_tag.get_text())) if review_cnt_tag else 0

        # 10 관심수
        like_tag = soup.select_one("div[class*='Like__Container'] span")
        like_cnt = extract_number(like_tag.get_text()) if like_tag else None

        # 11 스타일 태그
        tag_items = soup.select("ul[class*='ProductTags__List'] span")
        styles = ",".join([t.get_text(strip=True) for t in tag_items])

        # 12 실측사이즈 JSON
        size_json = "[]"

        # 13 핏/계절감 JSON
        fit_json = json.dumps({"핏": [], "계절감": []}, ensure_ascii=False)

        # -----------------------------
        # INSERT 값 (DB 순서대로)
        # -----------------------------
        values = (
            gid, product_name, brand, normal_price, sale_price,
            upper_category, lower_category, gender, rating,
            like_cnt, review_cnt, size_json, discount,
            fit_json, cumulative, styles
        )

        cursor.execute(insert_sql, values)
        conn.commit()

    except Exception as e:
        print(f"오류: {gid}, 이유: {e}")
        with open("error_log.txt", "a", encoding="utf-8") as log:
            log.write(f"{gid}, {e}\n")

        # DB 끊겼으면 재연결
        try:
            conn.ping(reconnect=True)
        except:
            conn = get_connection()
            cursor = conn.cursor()

print("모든 작업 완료!")

driver.quit()
conn.close()
# Out:
# DB 테이블 컬럼: ['product_id', 'product_name', 'brand', 'original_price', 'sale_price', 'upper_category', 'lower_category', 'gender', 'rating', 'wish_count', 'review_count', 'size_info', 'discount_rate', 'fit_season', 'cumulative_sales', 'style']
# 총 컬럼 수: 16
# 이미 저장된 상품 수: 0개
# 전체 상품 수: 59914
# 이번에 시작할 인덱스: 0
# 크롤링 시작!
# [1/59914] 상품 1844582 처리 중...
# [2/59914] 상품 1926048 처리 중...
# [3/59914] 상품 2574822 처리 중...
# [4/59914] 상품 1551840 처리 중...
# [5/59914] 상품 3791988 처리 중...
# [6/59914] 상품 1926034 처리 중...
# [7/59914] 상품 2112061 처리 중...
# [8/59914] 상품 1551839 처리 중...
# [9/59914] 상품 1149329 처리 중...
# [10/59914] 상품 4274049 처리 중...
# [11/59914] 상품 750908 처리 중...
# [12/59914] 상품 2112059 처리 중...
# [13/59914] 상품 4757347 처리 중...
# [14/59914] 상품 1168906 처리 중...
# [15/59914] 상품 3228764 처리 중...
# [16/59914] 상품 3231055 처리 중...
# [17/59914] 상품 2578996 처리 중...
# [18/59914] 상품 3674341 처리 중...
# [19/59914] 상품 3663072 처리 중...
# [20/59914] 상품 1735427 처리 중...
# [21/59914] 상품 4993414 처리 중...
# [22/59914] 상품 2744549 처리 중...
# [23/59914] 상품 1924274 처리 중...
# [24/59914] 상품 2926541 처리 중...

# %%
import time
import csv
import random
from curl_cffi import requests # 일반 requests 대신 curl_cffi 사용 권장 (차단 방지)

# ==========================================
# 1. 설정
# ==========================================
# 수집하려는 카테고리 코드 (예: 101001 = 숏패딩 등, 원하시는 코드로 변경 가능)
# 만약 URL에 있던 101001을 그대로 쓰시려면 아래처럼 하세요.
TARGET_CATEGORY = "101001"

OUTPUT_FILENAME = "musinsa_hat_ids.csv"
PAGE_SIZE = 100 # 한번에 가져올 개수 (API상 100이 최대일 가능성 높음)

# ==========================================
# 2. 크롤링 함수
# ==========================================
def collect_ids():
    goods_ids = []
    page = 1
    
    # 세션 설정 (헤더 포함)
    session = requests.Session(impersonate="chrome")
    session.headers.update({
        "Referer": "https://www.musinsa.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
    })

    print(f"🚀 ID 수집 시작 (카테고리: {TARGET_CATEGORY})")

    while True:
        try:
            # API URL 구성 (gf=A: 필터, caller: 호출처)
            url = f"https://api.musinsa.com/api2/dp/v1/plp/goods?gf=A&category={TARGET_CATEGORY}&caller=CATEGORY&page={page}&size={PAGE_SIZE}"
            
            print(f"📄 페이지 {page} 요청 중...", end=" ")
            
            # 요청 및 딜레이
            time.sleep(random.uniform(0.5, 1.0)) # 너무 빠르면 차단되니 살짝 대기
            response = session.get(url, timeout=10)
            
            if response.status_code != 200:
                print(f"⚠️ HTTP 에러: {response.status_code}")
                break
            
            # JSON 파싱
            data = response.json()
            
            # 데이터 위치 확인
            if "data" not in data or "list" not in data["data"]:
                print("❌ 데이터 구조가 예상과 다릅니다. 종료합니다.")
                break
                
            items = data["data"]["list"]
            if not items:
                print("⚠️ 더 이상 상품이 없습니다 (빈 리스트). 종료합니다.")
                break
                
            # ID 추출 및 저장
            current_ids = [item["goodsNo"] for item in items]
            goods_ids.extend(current_ids)
            
            print(f"✅ {len(current_ids)}개 확보 (누적: {len(goods_ids)}개)")

            # 페이지네이션 정보 확인 (종료 조건)
            pagination = data["data"].get("pagination", {})
            total_pages = pagination.get("totalPages", 1)
            has_next = pagination.get("hasNext", False)
            
            # 마지막 페이지 도달 시 종료
            if page >= total_pages or not has_next:
                print("🏁 마지막 페이지 도달! 수집을 종료합니다.")
                break
            
            # 다음 페이지로 이동
            page += 1
            
            # (선택) 테스트용: 너무 많으면 5페이지만 하고 멈추기
            # if page > 5: break 

        except Exception as e:
            print(f"\n❌ 에러 발생: {e}")
            break

    return goods_ids

# ==========================================
# 3. CSV 저장 및 실행
# ==========================================
if __name__ == "__main__":
    ids = collect_ids()
    
    if ids:
        print(f"\n💾 CSV 파일로 저장 중... ({len(ids)}개)")
        with open(OUTPUT_FILENAME, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["goods_no"]) # 헤더
            for gid in ids:
                writer.writerow([gid])
        print(f"🎉 저장 완료: {OUTPUT_FILENAME}")
    else:
        print("⚠️ 수집된 데이터가 없습니다.")
# Out:
# 🚀 ID 수집 시작 (카테고리: 101001)
# 📄 페이지 1 요청 중... ✅ 100개 확보 (누적: 100개)
# 📄 페이지 2 요청 중... ✅ 100개 확보 (누적: 200개)
# 📄 페이지 3 요청 중... ✅ 100개 확보 (누적: 300개)
# 📄 페이지 4 요청 중... ✅ 100개 확보 (누적: 400개)
# 📄 페이지 5 요청 중... ✅ 100개 확보 (누적: 500개)
# 📄 페이지 6 요청 중... ✅ 100개 확보 (누적: 600개)
# 📄 페이지 7 요청 중... ✅ 100개 확보 (누적: 700개)
# 📄 페이지 8 요청 중... ✅ 100개 확보 (누적: 800개)
# 📄 페이지 9 요청 중... ✅ 100개 확보 (누적: 900개)
# 📄 페이지 10 요청 중... ✅ 100개 확보 (누적: 1000개)
# 📄 페이지 11 요청 중... ✅ 100개 확보 (누적: 1100개)
# 📄 페이지 12 요청 중... ✅ 100개 확보 (누적: 1200개)
# 📄 페이지 13 요청 중... ✅ 100개 확보 (누적: 1300개)
# 📄 페이지 14 요청 중... ✅ 100개 확보 (누적: 1400개)
# 📄 페이지 15 요청 중... ✅ 100개 확보 (누적: 1500개)
# 📄 페이지 16 요청 중... ✅ 100개 확보 (누적: 1600개)
# 📄 페이지 17 요청 중... ✅ 100개 확보 (누적: 1700개)
# 📄 페이지 18 요청 중... ✅ 100개 확보 (누적: 1800개)
# 📄 페이지 19 요청 중... ✅ 100개 확보 (누적: 1900개)
# 📄 페이지 20 요청 중... ✅ 100개 확보 (누적: 2000개)
# 📄 페이지 21 요청 중... ✅ 100개 확보 (누적: 2100개)
# 📄 페이지 22 요청 중... ✅ 100개 확보 (누적: 2200개)
# 📄 페이지 23 요청 중... ✅ 100개 확보 (누적: 2300개)
# 📄 페이지 24 요청 중... ✅ 100개 확보 (누적: 2400개)
# 📄 페이지 25 요청 중... ✅ 100개 확보 (누적: 2500개)
# 📄 페이지 26 요청 중... ✅ 100개 확보 (누적: 2600개)
# 📄 페이지 27 요청 중... ✅ 100개 확보 (누적: 2700개)
# 📄 페이지 28 요청 중... ✅ 100개 확보 (누적: 2800개)
# 📄 페이지 29 요청 중... ✅ 100개 확보 (누적: 2900개)
# 📄 페이지 30 요청 중... ✅ 100개 확보 (누적: 3000개)
# 📄 페이지 31 요청 중... ✅ 100개 확보 (누적: 3100개)
# 📄 페이지 32 요청 중... ✅ 100개 확보 (누적: 3200개)
# 📄 페이지 33 요청 중... ✅ 100개 확보 (누적: 3300개)
# 📄 페이지 34 요청 중... ✅ 100개 확보 (누적: 3400개)
# 📄 페이지 35 요청 중... ✅ 100개 확보 (누적: 3500개)
# 📄 페이지 36 요청 중... ✅ 100개 확보 (누적: 3600개)
# 📄 페이지 37 요청 중... ✅ 100개 확보 (누적: 3700개)
# 📄 페이지 38 요청 중... ✅ 100개 확보 (누적: 3800개)
# 📄 페이지 39 요청 중... ✅ 100개 확보 (누적: 3900개)
# 📄 페이지 40 요청 중... ✅ 100개 확보 (누적: 4000개)
# 📄 페이지 41 요청 중... ✅ 100개 확보 (누적: 4100개)
# 📄 페이지 42 요청 중... ✅ 100개 확보 (누적: 4200개)
# 📄 페이지 43 요청 중... ✅ 100개 확보 (누적: 4300개)
# 📄 페이지 44 요청 중... ✅ 100개 확보 (누적: 4400개)
# 📄 페이지 45 요청 중... ✅ 100개 확보 (누적: 4500개)
# 📄 페이지 46 요청 중... ✅ 100개 확보 (누적: 4600개)
# 📄 페이지 47 요청 중... ✅ 100개 확보 (누적: 4700개)
# 📄 페이지 48 요청 중... ✅ 100개 확보 (누적: 4800개)
# 📄 페이지 49 요청 중... ✅ 100개 확보 (누적: 4900개)
# 📄 페이지 50 요청 중... ✅ 100개 확보 (누적: 5000개)
# 📄 페이지 51 요청 중... ✅ 100개 확보 (누적: 5100개)
# 📄 페이지 52 요청 중... ✅ 100개 확보 (누적: 5200개)
# 📄 페이지 53 요청 중... ✅ 100개 확보 (누적: 5300개)
# 📄 페이지 54 요청 중... ✅ 100개 확보 (누적: 5400개)
# 📄 페이지 55 요청 중... ✅ 100개 확보 (누적: 5500개)
# 📄 페이지 56 요청 중... ✅ 100개 확보 (누적: 5600개)
# 📄 페이지 57 요청 중... ✅ 100개 확보 (누적: 5700개)
# 📄 페이지 58 요청 중... ✅ 100개 확보 (누적: 5800개)
# 📄 페이지 59 요청 중... ✅ 100개 확보 (누적: 5900개)
# 📄 페이지 60 요청 중... ✅ 100개 확보 (누적: 6000개)
# 📄 페이지 61 요청 중... ✅ 100개 확보 (누적: 6100개)
# 📄 페이지 62 요청 중... ✅ 100개 확보 (누적: 6200개)
# 📄 페이지 63 요청 중... ✅ 100개 확보 (누적: 6300개)
# 📄 페이지 64 요청 중... ✅ 100개 확보 (누적: 6400개)
# 📄 페이지 65 요청 중... ✅ 100개 확보 (누적: 6500개)
# 📄 페이지 66 요청 중... ✅ 100개 확보 (누적: 6600개)
# 📄 페이지 67 요청 중... ✅ 100개 확보 (누적: 6700개)
# 📄 페이지 68 요청 중... ✅ 100개 확보 (누적: 6800개)
# 📄 페이지 69 요청 중... ✅ 100개 확보 (누적: 6900개)
# 📄 페이지 70 요청 중... ✅ 100개 확보 (누적: 7000개)
# 📄 페이지 71 요청 중... ✅ 100개 확보 (누적: 7100개)
# 📄 페이지 72 요청 중... ✅ 100개 확보 (누적: 7200개)
# 📄 페이지 73 요청 중... ✅ 100개 확보 (누적: 7300개)
# 📄 페이지 74 요청 중... ✅ 100개 확보 (누적: 7400개)
# 📄 페이지 75 요청 중... ✅ 100개 확보 (누적: 7500개)
# 📄 페이지 76 요청 중... ✅ 100개 확보 (누적: 7600개)
# 📄 페이지 77 요청 중... ✅ 100개 확보 (누적: 7700개)
# 📄 페이지 78 요청 중... ✅ 100개 확보 (누적: 7800개)
# 📄 페이지 79 요청 중... ✅ 100개 확보 (누적: 7900개)
# 📄 페이지 80 요청 중... ✅ 100개 확보 (누적: 8000개)
# 📄 페이지 81 요청 중... ✅ 100개 확보 (누적: 8100개)
# 📄 페이지 82 요청 중... ✅ 100개 확보 (누적: 8200개)
# 📄 페이지 83 요청 중... ✅ 100개 확보 (누적: 8300개)
# 📄 페이지 84 요청 중... ✅ 100개 확보 (누적: 8400개)
# 📄 페이지 85 요청 중... ✅ 100개 확보 (누적: 8500개)
# 📄 페이지 86 요청 중... ✅ 100개 확보 (누적: 8600개)
# 📄 페이지 87 요청 중... ✅ 100개 확보 (누적: 8700개)
# 📄 페이지 88 요청 중... ✅ 100개 확보 (누적: 8800개)
# 📄 페이지 89 요청 중... ✅ 100개 확보 (누적: 8900개)
# 📄 페이지 90 요청 중... ✅ 100개 확보 (누적: 9000개)
# 📄 페이지 91 요청 중... ✅ 100개 확보 (누적: 9100개)
# 📄 페이지 92 요청 중... ✅ 100개 확보 (누적: 9200개)
# 📄 페이지 93 요청 중... ✅ 100개 확보 (누적: 9300개)
# 📄 페이지 94 요청 중... ✅ 100개 확보 (누적: 9400개)
# 📄 페이지 95 요청 중... ✅ 100개 확보 (누적: 9500개)
# 📄 페이지 96 요청 중... ✅ 100개 확보 (누적: 9600개)
# 📄 페이지 97 요청 중... ✅ 100개 확보 (누적: 9700개)
# 📄 페이지 98 요청 중... ✅ 100개 확보 (누적: 9800개)
# 📄 페이지 99 요청 중... ✅ 100개 확보 (누적: 9900개)
# 📄 페이지 100 요청 중... ✅ 100개 확보 (누적: 10000개)
# 📄 페이지 101 요청 중... ✅ 100개 확보 (누적: 10100개)
# 📄 페이지 102 요청 중... ✅ 100개 확보 (누적: 10200개)
# 📄 페이지 103 요청 중... ✅ 100개 확보 (누적: 10300개)
# 📄 페이지 104 요청 중... ✅ 100개 확보 (누적: 10400개)
# 📄 페이지 105 요청 중... ✅ 100개 확보 (누적: 10500개)
# 📄 페이지 106 요청 중... ✅ 100개 확보 (누적: 10600개)
# 📄 페이지 107 요청 중... ✅ 100개 확보 (누적: 10700개)
# 📄 페이지 108 요청 중... ✅ 100개 확보 (누적: 10800개)
# 📄 페이지 109 요청 중... ✅ 100개 확보 (누적: 10900개)
# 📄 페이지 110 요청 중... ✅ 100개 확보 (누적: 11000개)
# 📄 페이지 111 요청 중... ✅ 100개 확보 (누적: 11100개)
# 📄 페이지 112 요청 중... ✅ 100개 확보 (누적: 11200개)
# 📄 페이지 113 요청 중... ✅ 100개 확보 (누적: 11300개)
# 📄 페이지 114 요청 중... ✅ 100개 확보 (누적: 11400개)
# 📄 페이지 115 요청 중... ✅ 100개 확보 (누적: 11500개)
# 📄 페이지 116 요청 중... ✅ 100개 확보 (누적: 11600개)
# 📄 페이지 117 요청 중... ✅ 100개 확보 (누적: 11700개)
# 📄 페이지 118 요청 중... ✅ 100개 확보 (누적: 11800개)
# 📄 페이지 119 요청 중... ✅ 100개 확보 (누적: 11900개)
# 📄 페이지 120 요청 중... ✅ 100개 확보 (누적: 12000개)
# 📄 페이지 121 요청 중... ✅ 100개 확보 (누적: 12100개)
# 📄 페이지 122 요청 중... ✅ 100개 확보 (누적: 12200개)
# 📄 페이지 123 요청 중... ✅ 100개 확보 (누적: 12300개)
# 📄 페이지 124 요청 중... ✅ 100개 확보 (누적: 12400개)
# 📄 페이지 125 요청 중... ✅ 100개 확보 (누적: 12500개)
# 📄 페이지 126 요청 중... ✅ 100개 확보 (누적: 12600개)
# 📄 페이지 127 요청 중... ✅ 100개 확보 (누적: 12700개)
# 📄 페이지 128 요청 중... ✅ 100개 확보 (누적: 12800개)
# 📄 페이지 129 요청 중... ✅ 100개 확보 (누적: 12900개)
# 📄 페이지 130 요청 중... ✅ 100개 확보 (누적: 13000개)
# 📄 페이지 131 요청 중... ✅ 100개 확보 (누적: 13100개)
# 📄 페이지 132 요청 중... ✅ 100개 확보 (누적: 13200개)
# 📄 페이지 133 요청 중... ✅ 100개 확보 (누적: 13300개)
# 📄 페이지 134 요청 중... ✅ 100개 확보 (누적: 13400개)
# 📄 페이지 135 요청 중... ✅ 100개 확보 (누적: 13500개)
# 📄 페이지 136 요청 중... ✅ 100개 확보 (누적: 13600개)
# 📄 페이지 137 요청 중... ✅ 100개 확보 (누적: 13700개)
# 📄 페이지 138 요청 중... ✅ 100개 확보 (누적: 13800개)
# 📄 페이지 139 요청 중... ✅ 100개 확보 (누적: 13900개)
# 📄 페이지 140 요청 중... ✅ 100개 확보 (누적: 14000개)
# 📄 페이지 141 요청 중... ✅ 100개 확보 (누적: 14100개)
# 📄 페이지 142 요청 중... ✅ 100개 확보 (누적: 14200개)
# 📄 페이지 143 요청 중... ✅ 100개 확보 (누적: 14300개)
# 📄 페이지 144 요청 중... ✅ 100개 확보 (누적: 14400개)
# 📄 페이지 145 요청 중... ✅ 100개 확보 (누적: 14500개)
# 📄 페이지 146 요청 중... ✅ 100개 확보 (누적: 14600개)
# 📄 페이지 147 요청 중... ✅ 100개 확보 (누적: 14700개)
# 📄 페이지 148 요청 중... ✅ 100개 확보 (누적: 14800개)
# 📄 페이지 149 요청 중... ✅ 100개 확보 (누적: 14900개)
# 📄 페이지 150 요청 중... ✅ 100개 확보 (누적: 15000개)
# 📄 페이지 151 요청 중... ✅ 100개 확보 (누적: 15100개)
# 📄 페이지 152 요청 중... ✅ 100개 확보 (누적: 15200개)
# 📄 페이지 153 요청 중... ✅ 100개 확보 (누적: 15300개)
# 📄 페이지 154 요청 중... ✅ 100개 확보 (누적: 15400개)
# 📄 페이지 155 요청 중... ✅ 100개 확보 (누적: 15500개)
# 📄 페이지 156 요청 중... ✅ 100개 확보 (누적: 15600개)
# 📄 페이지 157 요청 중... ✅ 100개 확보 (누적: 15700개)
# 📄 페이지 158 요청 중... ✅ 100개 확보 (누적: 15800개)
# 📄 페이지 159 요청 중... ✅ 100개 확보 (누적: 15900개)
# 📄 페이지 160 요청 중... ✅ 100개 확보 (누적: 16000개)
# 📄 페이지 161 요청 중... ✅ 100개 확보 (누적: 16100개)
# 📄 페이지 162 요청 중... ✅ 100개 확보 (누적: 16200개)
# 📄 페이지 163 요청 중... ✅ 100개 확보 (누적: 16300개)
# 📄 페이지 164 요청 중... ✅ 100개 확보 (누적: 16400개)
# 📄 페이지 165 요청 중... ✅ 100개 확보 (누적: 16500개)
# 📄 페이지 166 요청 중... ✅ 100개 확보 (누적: 16600개)
# 📄 페이지 167 요청 중... ✅ 100개 확보 (누적: 16700개)
# 📄 페이지 168 요청 중... ✅ 100개 확보 (누적: 16800개)
# 📄 페이지 169 요청 중... ✅ 100개 확보 (누적: 16900개)
# 📄 페이지 170 요청 중... ✅ 100개 확보 (누적: 17000개)
# 📄 페이지 171 요청 중... ✅ 100개 확보 (누적: 17100개)
# 📄 페이지 172 요청 중... ✅ 100개 확보 (누적: 17200개)
# 📄 페이지 173 요청 중... ✅ 100개 확보 (누적: 17300개)
# 📄 페이지 174 요청 중... ✅ 100개 확보 (누적: 17400개)
# 📄 페이지 175 요청 중... ✅ 100개 확보 (누적: 17500개)
# 📄 페이지 176 요청 중... ✅ 100개 확보 (누적: 17600개)
# 📄 페이지 177 요청 중... ✅ 100개 확보 (누적: 17700개)
# 📄 페이지 178 요청 중... ✅ 100개 확보 (누적: 17800개)
# 📄 페이지 179 요청 중... ✅ 100개 확보 (누적: 17900개)
# 📄 페이지 180 요청 중... ✅ 100개 확보 (누적: 18000개)
# 📄 페이지 181 요청 중... ✅ 100개 확보 (누적: 18100개)
# 📄 페이지 182 요청 중... ✅ 100개 확보 (누적: 18200개)
# 📄 페이지 183 요청 중... ✅ 100개 확보 (누적: 18300개)
# 📄 페이지 184 요청 중... ✅ 100개 확보 (누적: 18400개)
# 📄 페이지 185 요청 중... ✅ 100개 확보 (누적: 18500개)
# 📄 페이지 186 요청 중... ✅ 100개 확보 (누적: 18600개)
# 📄 페이지 187 요청 중... ✅ 100개 확보 (누적: 18700개)
# 📄 페이지 188 요청 중... ✅ 100개 확보 (누적: 18800개)
# 📄 페이지 189 요청 중... ✅ 100개 확보 (누적: 18900개)
# 📄 페이지 190 요청 중... ✅ 100개 확보 (누적: 19000개)
# 📄 페이지 191 요청 중... ✅ 100개 확보 (누적: 19100개)
# 📄 페이지 192 요청 중... ✅ 100개 확보 (누적: 19200개)
# 📄 페이지 193 요청 중... ✅ 100개 확보 (누적: 19300개)
# 📄 페이지 194 요청 중... ✅ 100개 확보 (누적: 19400개)
# 📄 페이지 195 요청 중... ✅ 100개 확보 (누적: 19500개)
# 📄 페이지 196 요청 중... ✅ 100개 확보 (누적: 19600개)
# 📄 페이지 197 요청 중... ✅ 100개 확보 (누적: 19700개)
# 📄 페이지 198 요청 중... ✅ 100개 확보 (누적: 19800개)
# 📄 페이지 199 요청 중... ✅ 100개 확보 (누적: 19900개)
# 📄 페이지 200 요청 중... ✅ 100개 확보 (누적: 20000개)
# 📄 페이지 201 요청 중... ✅ 100개 확보 (누적: 20100개)
# 📄 페이지 202 요청 중... ✅ 100개 확보 (누적: 20200개)
# 📄 페이지 203 요청 중... ✅ 100개 확보 (누적: 20300개)
# 📄 페이지 204 요청 중... ✅ 100개 확보 (누적: 20400개)
# 📄 페이지 205 요청 중... ✅ 100개 확보 (누적: 20500개)
# 📄 페이지 206 요청 중... ✅ 100개 확보 (누적: 20600개)
# 📄 페이지 207 요청 중... ✅ 100개 확보 (누적: 20700개)
# 📄 페이지 208 요청 중... ✅ 100개 확보 (누적: 20800개)
# 📄 페이지 209 요청 중... ✅ 100개 확보 (누적: 20900개)
# 📄 페이지 210 요청 중... ✅ 100개 확보 (누적: 21000개)
# 📄 페이지 211 요청 중... ✅ 100개 확보 (누적: 21100개)
# 📄 페이지 212 요청 중... ✅ 100개 확보 (누적: 21200개)
# 📄 페이지 213 요청 중... ✅ 100개 확보 (누적: 21300개)
# 📄 페이지 214 요청 중... ✅ 100개 확보 (누적: 21400개)
# 📄 페이지 215 요청 중... ✅ 100개 확보 (누적: 21500개)
# 📄 페이지 216 요청 중... ✅ 100개 확보 (누적: 21600개)
# 📄 페이지 217 요청 중... ✅ 100개 확보 (누적: 21700개)
# 📄 페이지 218 요청 중... ✅ 100개 확보 (누적: 21800개)
# 📄 페이지 219 요청 중... ✅ 100개 확보 (누적: 21900개)
# 📄 페이지 220 요청 중... ✅ 100개 확보 (누적: 22000개)
# 📄 페이지 221 요청 중... ✅ 100개 확보 (누적: 22100개)
# 📄 페이지 222 요청 중... ✅ 100개 확보 (누적: 22200개)
# 📄 페이지 223 요청 중... ✅ 100개 확보 (누적: 22300개)
# 📄 페이지 224 요청 중... ✅ 100개 확보 (누적: 22400개)
# 📄 페이지 225 요청 중... ✅ 100개 확보 (누적: 22500개)
# 📄 페이지 226 요청 중... ✅ 100개 확보 (누적: 22600개)
# 📄 페이지 227 요청 중... ✅ 100개 확보 (누적: 22700개)
# 📄 페이지 228 요청 중... ✅ 100개 확보 (누적: 22800개)
# 📄 페이지 229 요청 중... ✅ 100개 확보 (누적: 22900개)
# 📄 페이지 230 요청 중... ✅ 100개 확보 (누적: 23000개)
# 📄 페이지 231 요청 중... ✅ 100개 확보 (누적: 23100개)
# 📄 페이지 232 요청 중... ✅ 100개 확보 (누적: 23200개)
# 📄 페이지 233 요청 중... ✅ 100개 확보 (누적: 23300개)
# 📄 페이지 234 요청 중... ✅ 100개 확보 (누적: 23400개)
# 📄 페이지 235 요청 중... ✅ 100개 확보 (누적: 23500개)
# 📄 페이지 236 요청 중... ✅ 100개 확보 (누적: 23600개)
# 📄 페이지 237 요청 중... ✅ 100개 확보 (누적: 23700개)
# 📄 페이지 238 요청 중... ✅ 100개 확보 (누적: 23800개)
# 📄 페이지 239 요청 중... ✅ 100개 확보 (누적: 23900개)
# 📄 페이지 240 요청 중... ✅ 100개 확보 (누적: 24000개)
# 📄 페이지 241 요청 중... ✅ 100개 확보 (누적: 24100개)
# 📄 페이지 242 요청 중... ✅ 100개 확보 (누적: 24200개)
# 📄 페이지 243 요청 중... ✅ 100개 확보 (누적: 24300개)
# 📄 페이지 244 요청 중... ✅ 100개 확보 (누적: 24400개)
# 📄 페이지 245 요청 중... ✅ 100개 확보 (누적: 24500개)
# 📄 페이지 246 요청 중... ✅ 100개 확보 (누적: 24600개)
# 📄 페이지 247 요청 중... ✅ 100개 확보 (누적: 24700개)
# 📄 페이지 248 요청 중... ✅ 100개 확보 (누적: 24800개)
# 📄 페이지 249 요청 중... ✅ 100개 확보 (누적: 24900개)
# 📄 페이지 250 요청 중... ✅ 100개 확보 (누적: 25000개)
# 📄 페이지 251 요청 중... ✅ 100개 확보 (누적: 25100개)
# 📄 페이지 252 요청 중... ✅ 100개 확보 (누적: 25200개)
# 📄 페이지 253 요청 중... ✅ 100개 확보 (누적: 25300개)
# 📄 페이지 254 요청 중... ✅ 100개 확보 (누적: 25400개)
# 📄 페이지 255 요청 중... ✅ 100개 확보 (누적: 25500개)
# 📄 페이지 256 요청 중... ✅ 100개 확보 (누적: 25600개)
# 📄 페이지 257 요청 중... ✅ 100개 확보 (누적: 25700개)
# 📄 페이지 258 요청 중... ✅ 100개 확보 (누적: 25800개)
# 📄 페이지 259 요청 중... ✅ 100개 확보 (누적: 25900개)
# 📄 페이지 260 요청 중... ✅ 100개 확보 (누적: 26000개)
# 📄 페이지 261 요청 중... ✅ 100개 확보 (누적: 26100개)
# 📄 페이지 262 요청 중... ✅ 100개 확보 (누적: 26200개)
# 📄 페이지 263 요청 중... ✅ 100개 확보 (누적: 26300개)
# 📄 페이지 264 요청 중... ✅ 100개 확보 (누적: 26400개)
# 📄 페이지 265 요청 중... ✅ 100개 확보 (누적: 26500개)
# 📄 페이지 266 요청 중... ✅ 100개 확보 (누적: 26600개)
# 📄 페이지 267 요청 중... ✅ 100개 확보 (누적: 26700개)
# 📄 페이지 268 요청 중... ✅ 100개 확보 (누적: 26800개)
# 📄 페이지 269 요청 중... ✅ 100개 확보 (누적: 26900개)
# 📄 페이지 270 요청 중... ✅ 100개 확보 (누적: 27000개)
# 📄 페이지 271 요청 중... ✅ 100개 확보 (누적: 27100개)
# 📄 페이지 272 요청 중... ✅ 100개 확보 (누적: 27200개)
# 📄 페이지 273 요청 중... ✅ 100개 확보 (누적: 27300개)
# 📄 페이지 274 요청 중... ✅ 100개 확보 (누적: 27400개)
# 📄 페이지 275 요청 중... ✅ 100개 확보 (누적: 27500개)
# 📄 페이지 276 요청 중... ✅ 100개 확보 (누적: 27600개)
# 📄 페이지 277 요청 중... ✅ 100개 확보 (누적: 27700개)
# 📄 페이지 278 요청 중... ✅ 100개 확보 (누적: 27800개)
# 📄 페이지 279 요청 중... ✅ 100개 확보 (누적: 27900개)
# 📄 페이지 280 요청 중... ✅ 100개 확보 (누적: 28000개)
# 📄 페이지 281 요청 중... ✅ 100개 확보 (누적: 28100개)
# 📄 페이지 282 요청 중... ✅ 100개 확보 (누적: 28200개)
# 📄 페이지 283 요청 중... ✅ 100개 확보 (누적: 28300개)
# 📄 페이지 284 요청 중... ✅ 100개 확보 (누적: 28400개)
# 📄 페이지 285 요청 중... ✅ 100개 확보 (누적: 28500개)
# 📄 페이지 286 요청 중... ✅ 100개 확보 (누적: 28600개)
# 📄 페이지 287 요청 중... ✅ 100개 확보 (누적: 28700개)
# 📄 페이지 288 요청 중... ✅ 100개 확보 (누적: 28800개)
# 📄 페이지 289 요청 중... ✅ 100개 확보 (누적: 28900개)
# 📄 페이지 290 요청 중... ✅ 100개 확보 (누적: 29000개)
# 📄 페이지 291 요청 중... ✅ 100개 확보 (누적: 29100개)
# 📄 페이지 292 요청 중... ✅ 100개 확보 (누적: 29200개)
# 📄 페이지 293 요청 중... ✅ 100개 확보 (누적: 29300개)
# 📄 페이지 294 요청 중... ✅ 100개 확보 (누적: 29400개)
# 📄 페이지 295 요청 중... ✅ 100개 확보 (누적: 29500개)
# 📄 페이지 296 요청 중... ✅ 100개 확보 (누적: 29600개)
# 📄 페이지 297 요청 중... ✅ 100개 확보 (누적: 29700개)
# 📄 페이지 298 요청 중... ✅ 100개 확보 (누적: 29800개)
# 📄 페이지 299 요청 중... ✅ 100개 확보 (누적: 29900개)
# 📄 페이지 300 요청 중... ✅ 100개 확보 (누적: 30000개)
# 📄 페이지 301 요청 중... ✅ 100개 확보 (누적: 30100개)
# 📄 페이지 302 요청 중... ✅ 100개 확보 (누적: 30200개)
# 📄 페이지 303 요청 중... ✅ 100개 확보 (누적: 30300개)
# 📄 페이지 304 요청 중... ✅ 100개 확보 (누적: 30400개)
# 📄 페이지 305 요청 중... ✅ 100개 확보 (누적: 30500개)
# 📄 페이지 306 요청 중... ✅ 100개 확보 (누적: 30600개)
# 📄 페이지 307 요청 중... ✅ 100개 확보 (누적: 30700개)
# 📄 페이지 308 요청 중... ✅ 100개 확보 (누적: 30800개)
# 📄 페이지 309 요청 중... ✅ 100개 확보 (누적: 30900개)
# 📄 페이지 310 요청 중... ✅ 100개 확보 (누적: 31000개)
# 📄 페이지 311 요청 중... ✅ 100개 확보 (누적: 31100개)
# 📄 페이지 312 요청 중... ✅ 100개 확보 (누적: 31200개)
# 📄 페이지 313 요청 중... ✅ 100개 확보 (누적: 31300개)
# 📄 페이지 314 요청 중... ✅ 100개 확보 (누적: 31400개)
# 📄 페이지 315 요청 중... ✅ 100개 확보 (누적: 31500개)
# 📄 페이지 316 요청 중... ✅ 100개 확보 (누적: 31600개)
# 📄 페이지 317 요청 중... ✅ 100개 확보 (누적: 31700개)
# 📄 페이지 318 요청 중... ✅ 100개 확보 (누적: 31800개)
# 📄 페이지 319 요청 중... ✅ 100개 확보 (누적: 31900개)
# 📄 페이지 320 요청 중... ✅ 100개 확보 (누적: 32000개)
# 📄 페이지 321 요청 중... ✅ 100개 확보 (누적: 32100개)
# 📄 페이지 322 요청 중... ✅ 100개 확보 (누적: 32200개)
# 📄 페이지 323 요청 중... ✅ 100개 확보 (누적: 32300개)
# 📄 페이지 324 요청 중... ✅ 100개 확보 (누적: 32400개)
# 📄 페이지 325 요청 중... ✅ 100개 확보 (누적: 32500개)
# 📄 페이지 326 요청 중... ✅ 100개 확보 (누적: 32600개)
# 📄 페이지 327 요청 중... ✅ 100개 확보 (누적: 32700개)
# 📄 페이지 328 요청 중... ✅ 100개 확보 (누적: 32800개)
# 📄 페이지 329 요청 중... ✅ 100개 확보 (누적: 32900개)
# 📄 페이지 330 요청 중... ✅ 100개 확보 (누적: 33000개)
# 📄 페이지 331 요청 중... ✅ 100개 확보 (누적: 33100개)
# 📄 페이지 332 요청 중... ✅ 100개 확보 (누적: 33200개)
# 📄 페이지 333 요청 중... ✅ 100개 확보 (누적: 33300개)
# 📄 페이지 334 요청 중... ✅ 100개 확보 (누적: 33400개)
# 📄 페이지 335 요청 중... ✅ 100개 확보 (누적: 33500개)
# 📄 페이지 336 요청 중... ✅ 100개 확보 (누적: 33600개)
# 📄 페이지 337 요청 중... ✅ 100개 확보 (누적: 33700개)
# 📄 페이지 338 요청 중... ✅ 100개 확보 (누적: 33800개)
# 📄 페이지 339 요청 중... ✅ 100개 확보 (누적: 33900개)
# 📄 페이지 340 요청 중... ✅ 100개 확보 (누적: 34000개)
# 📄 페이지 341 요청 중... ✅ 100개 확보 (누적: 34100개)
# 📄 페이지 342 요청 중... ✅ 100개 확보 (누적: 34200개)
# 📄 페이지 343 요청 중... ✅ 100개 확보 (누적: 34300개)
# 📄 페이지 344 요청 중... ✅ 100개 확보 (누적: 34400개)
# 📄 페이지 345 요청 중... ✅ 100개 확보 (누적: 34500개)
# 📄 페이지 346 요청 중... ✅ 100개 확보 (누적: 34600개)
# 📄 페이지 347 요청 중... ✅ 100개 확보 (누적: 34700개)
# 📄 페이지 348 요청 중... ✅ 100개 확보 (누적: 34800개)
# 📄 페이지 349 요청 중... ✅ 100개 확보 (누적: 34900개)
# 📄 페이지 350 요청 중... ✅ 100개 확보 (누적: 35000개)
# 📄 페이지 351 요청 중... ✅ 100개 확보 (누적: 35100개)
# 📄 페이지 352 요청 중... ✅ 100개 확보 (누적: 35200개)
# 📄 페이지 353 요청 중... ✅ 100개 확보 (누적: 35300개)
# 📄 페이지 354 요청 중... ✅ 100개 확보 (누적: 35400개)
# 📄 페이지 355 요청 중... ✅ 100개 확보 (누적: 35500개)
# 📄 페이지 356 요청 중... ✅ 100개 확보 (누적: 35600개)
# 📄 페이지 357 요청 중... ✅ 100개 확보 (누적: 35700개)
# 📄 페이지 358 요청 중... ✅ 100개 확보 (누적: 35800개)
# 📄 페이지 359 요청 중... ✅ 100개 확보 (누적: 35900개)
# 📄 페이지 360 요청 중... ✅ 100개 확보 (누적: 36000개)
# 📄 페이지 361 요청 중... ✅ 100개 확보 (누적: 36100개)
# 📄 페이지 362 요청 중... ✅ 100개 확보 (누적: 36200개)
# 📄 페이지 363 요청 중... ✅ 100개 확보 (누적: 36300개)
# 📄 페이지 364 요청 중... ✅ 100개 확보 (누적: 36400개)
# 📄 페이지 365 요청 중... ✅ 100개 확보 (누적: 36500개)
# 📄 페이지 366 요청 중... ✅ 100개 확보 (누적: 36600개)
# 📄 페이지 367 요청 중... ✅ 100개 확보 (누적: 36700개)
# 📄 페이지 368 요청 중... ✅ 100개 확보 (누적: 36800개)
# 📄 페이지 369 요청 중... ✅ 100개 확보 (누적: 36900개)
# 📄 페이지 370 요청 중... ✅ 100개 확보 (누적: 37000개)
# 📄 페이지 371 요청 중... ✅ 100개 확보 (누적: 37100개)
# 📄 페이지 372 요청 중... ✅ 100개 확보 (누적: 37200개)
# 📄 페이지 373 요청 중... ✅ 100개 확보 (누적: 37300개)
# 📄 페이지 374 요청 중... ✅ 100개 확보 (누적: 37400개)
# 📄 페이지 375 요청 중... ✅ 100개 확보 (누적: 37500개)
# 📄 페이지 376 요청 중... ✅ 100개 확보 (누적: 37600개)
# 📄 페이지 377 요청 중... ✅ 100개 확보 (누적: 37700개)
# 📄 페이지 378 요청 중... ✅ 100개 확보 (누적: 37800개)
# 📄 페이지 379 요청 중... ✅ 100개 확보 (누적: 37900개)
# 📄 페이지 380 요청 중... ✅ 100개 확보 (누적: 38000개)
# 📄 페이지 381 요청 중... ✅ 100개 확보 (누적: 38100개)
# 📄 페이지 382 요청 중... ✅ 100개 확보 (누적: 38200개)
# 📄 페이지 383 요청 중... ✅ 100개 확보 (누적: 38300개)
# 📄 페이지 384 요청 중... ✅ 100개 확보 (누적: 38400개)
# 📄 페이지 385 요청 중... ✅ 100개 확보 (누적: 38500개)
# 📄 페이지 386 요청 중... ✅ 100개 확보 (누적: 38600개)
# 📄 페이지 387 요청 중... ✅ 100개 확보 (누적: 38700개)
# 📄 페이지 388 요청 중... ✅ 100개 확보 (누적: 38800개)
# 📄 페이지 389 요청 중... ✅ 100개 확보 (누적: 38900개)
# 📄 페이지 390 요청 중... ✅ 100개 확보 (누적: 39000개)
# 📄 페이지 391 요청 중... ✅ 100개 확보 (누적: 39100개)
# 📄 페이지 392 요청 중... ✅ 100개 확보 (누적: 39200개)
# 📄 페이지 393 요청 중... ✅ 100개 확보 (누적: 39300개)
# 📄 페이지 394 요청 중... ✅ 100개 확보 (누적: 39400개)
# 📄 페이지 395 요청 중... ✅ 100개 확보 (누적: 39500개)
# 📄 페이지 396 요청 중... ✅ 100개 확보 (누적: 39600개)
# 📄 페이지 397 요청 중... ✅ 100개 확보 (누적: 39700개)
# 📄 페이지 398 요청 중... ✅ 100개 확보 (누적: 39800개)
# 📄 페이지 399 요청 중... ✅ 100개 확보 (누적: 39900개)
# 📄 페이지 400 요청 중... ✅ 100개 확보 (누적: 40000개)
# 📄 페이지 401 요청 중... ✅ 100개 확보 (누적: 40100개)
# 📄 페이지 402 요청 중... ✅ 100개 확보 (누적: 40200개)
# 📄 페이지 403 요청 중... ✅ 100개 확보 (누적: 40300개)
# 📄 페이지 404 요청 중... ✅ 100개 확보 (누적: 40400개)
# 📄 페이지 405 요청 중... ✅ 100개 확보 (누적: 40500개)
# 📄 페이지 406 요청 중... ✅ 100개 확보 (누적: 40600개)
# 📄 페이지 407 요청 중... ✅ 100개 확보 (누적: 40700개)
# 📄 페이지 408 요청 중... ✅ 100개 확보 (누적: 40800개)
# 📄 페이지 409 요청 중... ✅ 100개 확보 (누적: 40900개)
# 📄 페이지 410 요청 중... ✅ 100개 확보 (누적: 41000개)
# 📄 페이지 411 요청 중... ✅ 100개 확보 (누적: 41100개)
# 📄 페이지 412 요청 중... ✅ 100개 확보 (누적: 41200개)
# 📄 페이지 413 요청 중... ✅ 100개 확보 (누적: 41300개)
# 📄 페이지 414 요청 중... ✅ 100개 확보 (누적: 41400개)
# 📄 페이지 415 요청 중... ✅ 100개 확보 (누적: 41500개)
# 📄 페이지 416 요청 중... ✅ 100개 확보 (누적: 41600개)
# 📄 페이지 417 요청 중... ✅ 100개 확보 (누적: 41700개)
# 📄 페이지 418 요청 중... ✅ 100개 확보 (누적: 41800개)
# 📄 페이지 419 요청 중... ✅ 100개 확보 (누적: 41900개)
# 📄 페이지 420 요청 중... ✅ 100개 확보 (누적: 42000개)
# 📄 페이지 421 요청 중... ✅ 100개 확보 (누적: 42100개)
# 📄 페이지 422 요청 중... ✅ 100개 확보 (누적: 42200개)
# 📄 페이지 423 요청 중... ✅ 100개 확보 (누적: 42300개)
# 📄 페이지 424 요청 중... ✅ 100개 확보 (누적: 42400개)
# 📄 페이지 425 요청 중... ✅ 100개 확보 (누적: 42500개)
# 📄 페이지 426 요청 중... ✅ 100개 확보 (누적: 42600개)
# 📄 페이지 427 요청 중... ✅ 100개 확보 (누적: 42700개)
# 📄 페이지 428 요청 중... ✅ 100개 확보 (누적: 42800개)
# 📄 페이지 429 요청 중... ✅ 100개 확보 (누적: 42900개)
# 📄 페이지 430 요청 중... ✅ 100개 확보 (누적: 43000개)
# 📄 페이지 431 요청 중... ✅ 100개 확보 (누적: 43100개)
# 📄 페이지 432 요청 중... ✅ 100개 확보 (누적: 43200개)
# 📄 페이지 433 요청 중... ✅ 100개 확보 (누적: 43300개)
# 📄 페이지 434 요청 중... ✅ 100개 확보 (누적: 43400개)
# 📄 페이지 435 요청 중... ✅ 100개 확보 (누적: 43500개)
# 📄 페이지 436 요청 중... ✅ 100개 확보 (누적: 43600개)
# 📄 페이지 437 요청 중... ✅ 100개 확보 (누적: 43700개)
# 📄 페이지 438 요청 중... ✅ 100개 확보 (누적: 43800개)
# 📄 페이지 439 요청 중... ✅ 100개 확보 (누적: 43900개)
# 📄 페이지 440 요청 중... ✅ 100개 확보 (누적: 44000개)
# 📄 페이지 441 요청 중... ✅ 100개 확보 (누적: 44100개)
# 📄 페이지 442 요청 중... ✅ 100개 확보 (누적: 44200개)
# 📄 페이지 443 요청 중... ✅ 100개 확보 (누적: 44300개)
# 📄 페이지 444 요청 중... ✅ 100개 확보 (누적: 44400개)
# 📄 페이지 445 요청 중... ✅ 100개 확보 (누적: 44500개)
# 📄 페이지 446 요청 중... ✅ 100개 확보 (누적: 44600개)
# 📄 페이지 447 요청 중... ✅ 100개 확보 (누적: 44700개)
# 📄 페이지 448 요청 중... ✅ 100개 확보 (누적: 44800개)
# 📄 페이지 449 요청 중... ✅ 100개 확보 (누적: 44900개)
# 📄 페이지 450 요청 중... ✅ 100개 확보 (누적: 45000개)
# 📄 페이지 451 요청 중... ✅ 100개 확보 (누적: 45100개)
# 📄 페이지 452 요청 중... ✅ 100개 확보 (누적: 45200개)
# 📄 페이지 453 요청 중... ✅ 100개 확보 (누적: 45300개)
# 📄 페이지 454 요청 중... ✅ 100개 확보 (누적: 45400개)
# 📄 페이지 455 요청 중... ✅ 100개 확보 (누적: 45500개)
# 📄 페이지 456 요청 중... ✅ 100개 확보 (누적: 45600개)
# 📄 페이지 457 요청 중... ✅ 100개 확보 (누적: 45700개)
# 📄 페이지 458 요청 중... ✅ 100개 확보 (누적: 45800개)
# 📄 페이지 459 요청 중... ✅ 100개 확보 (누적: 45900개)
# 📄 페이지 460 요청 중... ✅ 100개 확보 (누적: 46000개)
# 📄 페이지 461 요청 중... ✅ 100개 확보 (누적: 46100개)
# 📄 페이지 462 요청 중... ✅ 100개 확보 (누적: 46200개)
# 📄 페이지 463 요청 중... ✅ 100개 확보 (누적: 46300개)
# 📄 페이지 464 요청 중... ✅ 100개 확보 (누적: 46400개)
# 📄 페이지 465 요청 중... ✅ 100개 확보 (누적: 46500개)
# 📄 페이지 466 요청 중... ✅ 100개 확보 (누적: 46600개)
# 📄 페이지 467 요청 중... ✅ 100개 확보 (누적: 46700개)
# 📄 페이지 468 요청 중... ✅ 100개 확보 (누적: 46800개)
# 📄 페이지 469 요청 중... ✅ 100개 확보 (누적: 46900개)
# 📄 페이지 470 요청 중... ✅ 100개 확보 (누적: 47000개)
# 📄 페이지 471 요청 중... ✅ 100개 확보 (누적: 47100개)
# 📄 페이지 472 요청 중... ✅ 100개 확보 (누적: 47200개)
# 📄 페이지 473 요청 중... ✅ 100개 확보 (누적: 47300개)
# 📄 페이지 474 요청 중... ✅ 100개 확보 (누적: 47400개)
# 📄 페이지 475 요청 중... ✅ 100개 확보 (누적: 47500개)
# 📄 페이지 476 요청 중... ✅ 100개 확보 (누적: 47600개)
# 📄 페이지 477 요청 중... ✅ 100개 확보 (누적: 47700개)
# 📄 페이지 478 요청 중... ✅ 100개 확보 (누적: 47800개)
# 📄 페이지 479 요청 중... ✅ 100개 확보 (누적: 47900개)
# 📄 페이지 480 요청 중... ✅ 100개 확보 (누적: 48000개)
# 📄 페이지 481 요청 중... ✅ 100개 확보 (누적: 48100개)
# 📄 페이지 482 요청 중... ✅ 100개 확보 (누적: 48200개)
# 📄 페이지 483 요청 중... ✅ 100개 확보 (누적: 48300개)
# 📄 페이지 484 요청 중... ✅ 100개 확보 (누적: 48400개)
# 📄 페이지 485 요청 중... ✅ 100개 확보 (누적: 48500개)
# 📄 페이지 486 요청 중... ✅ 100개 확보 (누적: 48600개)
# 📄 페이지 487 요청 중... ✅ 100개 확보 (누적: 48700개)
# 📄 페이지 488 요청 중... ✅ 100개 확보 (누적: 48800개)
# 📄 페이지 489 요청 중... ✅ 100개 확보 (누적: 48900개)
# 📄 페이지 490 요청 중... ✅ 100개 확보 (누적: 49000개)
# 📄 페이지 491 요청 중... ✅ 100개 확보 (누적: 49100개)
# 📄 페이지 492 요청 중... ✅ 100개 확보 (누적: 49200개)
# 📄 페이지 493 요청 중... ✅ 100개 확보 (누적: 49300개)
# 📄 페이지 494 요청 중... ✅ 100개 확보 (누적: 49400개)
# 📄 페이지 495 요청 중... ✅ 100개 확보 (누적: 49500개)
# 📄 페이지 496 요청 중... ✅ 100개 확보 (누적: 49600개)
# 📄 페이지 497 요청 중... ✅ 100개 확보 (누적: 49700개)
# 📄 페이지 498 요청 중... ✅ 39개 확보 (누적: 49739개)
# 🏁 마지막 페이지 도달! 수집을 종료합니다.
#
# 💾 CSV 파일로 저장 중... (49739개)
# 🎉 저장 완료: musinsa_hat_ids.csv
